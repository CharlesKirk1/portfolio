# %% [markdown]
# <h2>#Python library set check</h2>
#     <p>Ensure that these libraries can be imported.  If not, you need to download them.  See classnotes or contact the instructor for help.
#     <p> Run each import separately to check success

# %%
import csv   # use this for basic cvs file input into Python; should be standard
print(csv)
# Out:
# <module 'csv' from '/Users/rhodes/anaconda3/lib/python3.7/csv.py'>

# %%
import pandas as pd    # we will use this for pandas library for dataframes and series
print(pd)
# Out:
# <module 'pandas' from '/Users/rhodes/anaconda3/lib/python3.7/site-packages/pandas/__init__.py'>

# %%
import numpy as np   #we will occasionally use this; it's a mathematics library
print(np)
# Out:
# <module 'numpy' from '/Users/rhodes/anaconda3/lib/python3.7/site-packages/numpy/__init__.py'>

# %%
import psycopg2 as pg   # use this for postgres database connection
print(pg)
# Out:
# <module 'psycopg2' from '/Users/rhodes/anaconda3/lib/python3.7/site-packages/psycopg2/__init__.py'>

# %% [markdown]
# Uncomment and run one of the commands in turn until success, only if psycopg2 failed to import

# %%
#pip install psycopg2-binary
#other pip commands to try if the above fails
#pip install psycopg2
#pip install psycopg2=2.8.4
#python -m pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org --trusted-host pypi.python.org psycopg2
